# %% [markdown]
# # Relic Denisty for $\chi\chi\to h_2 h_2$

# %%
import numpy as np
import pandas as pd
import subprocess
import time

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#good plots
plt.rcParams.update({'font.size': 20}) 
#plt.rc('font',size='18')

# %%
# Read the file with the good DM data
xd2 = pd.read_csv('DM2.csv')
del[xd2['Unnamed: 0']]

# %%
#Sum
xd2['BRS'] = xd2.BRx1x1u1U1+xd2.BRx1x1u2U2+xd2.BRx1x1u3U3+xd2.BRx1x1d1D1+xd2.BRx1x1d2D2+xd2.BRx1x1d3D3+xd2.BRx1x1e1E1+xd2.BRx1x1e2E2+xd2.BRx1x1e3E3+xd2.BRxx2d1U1+xd2.BRxx2d2U2+xd2.BRxx2d3U3+xd2.BRxx2e1Nu1+xd2.BRxx2e2Nu2+xd2.BRxx2e3Nu3+xd2.BRx1x1h1h1+xd2.BRx1x1h2h2+xd2.BRx1x1h1h2+xd2.BRx1x1gg+xd2.BRx1x1ww+xd2.BRx1x1ZZ+xd2.BRxxww+xd2.BRx2x2ww
# Out:
# /usr/local/lib/python3.4/dist-packages/pandas/core/computation/check.py:17: UserWarning: The installed version of numexpr 2.4 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
plt.figure(figsize=(8,6))
plt.semilogx(xd2.mChi1, (xd2.BRx1x1u1U1+xd2.BRx1x1u2U2+xd2.BRx1x1u3U3)/100.,'co',label=r'$\chi_1^0\chi_1^0\to u_i\bar{u}_i$')
plt.semilogx(xd2.mChi1, (xd2.BRx1x1d1D1+xd2.BRx1x1d2D2+xd2.BRx1x1d3D3)/100.,'yo',label=r'$\chi_1^0\chi_1^0\to d_i\bar{d}_i$')
plt.semilogx(xd2.mChi1, (xd2.BRx1x1e1E1+xd2.BRx1x1e2E2+xd2.BRx1x1e3E3)/100.,'bo',label=r'$\chi_1^0\chi_1^0\to e_i\bar{e}_i$')
plt.semilogx(xd2.mChi1, (xd2.BRxx2d1U1+xd2.BRxx2d2U2+xd2.BRxx2d3U3)/100.,'mo',label=r'$\chi^+\chi_2^0\to d_i\bar{u}_i$')
plt.semilogx(xd2.mChi1, (xd2.BRxx2e1Nu1+xd2.BRxx2e2Nu2+xd2.BRxx2e3Nu3)/100.,'go',label=r'$\chi^-\chi_2^0\to e_i\bar{\nu}_i$')

plt.semilogx(xd2.mChi1, xd2.BRx1x1h2h2/100.,'r*',label=r'$\chi_1^0\chi_1^0\to h_2h_2$')
plt.semilogx(xd2.mChi1, (xd2.BRx1x1h1h1+xd2.BRx1x1h1h2+xd2.BRx1x1gg+xd2.BRx1x1ww+xd2.BRx1x1ZZ+xd2.BRxxww+xd2.BRx2x2ww)/100.,'g*',label=r'others')
plt.semilogx(xd2.mChi1, (xd2.BRxxww+xd2.BRx2x2ww+xd2.BRx1x1ww+xd2.BRx1x1ZZ)/100.,'m*',label=r'others')
#plt.semilogx(xd2.mChi1, xd2.BRS/100.,'k*',label=r'$\Sigma$')
plt.legend(prop={'size':12},loc='best')
plt.show()

# %%
#h2 = xd2[np.logical_and(xd2.BRx1x1h2h2 >80, (xd2.BRxx2d1U1+xd2.BRxx2d2U2+xd2.BRxx2d3U3)> 20)]
h2 = xd2[np.logical_and(xd2.BRx1x1h2h2 >80, xd2.mChi1>xd2.mh2)]

# %%
h2.sv.max()
# Out:
# 1.0699999999999999e-27

# %%
h2 = h2.reset_index()
del[h2['index']]

# %%
print(xd2.shape[0], h2.shape[0])
# Out:
# 284 101

# %%
plt.figure(figsize=(14,6))

plt.subplot(121)
#plt.loglog(xDM.MDF, xDM.vS*xDM.YRC/np.sqrt(2),'co',markersize=4,label=r'$\Omega h^2$ + $\nu_\alpha$ ')
#plt.loglog(DI.MDF, DI.vS*DI.YRC/np.sqrt(2),'ro',label=r'+ DID')
plt.loglog(h2.MDF, h2.vS*h2.YRC/np.sqrt(2),'b*',label=r'')

#point
plt.text(200, 1.0e3, r'$\Omega_{\chi^0_1} < \Omega$', {'color': 'k', 'fontsize': 23})

#plt.grid()
#plt.title('general scan')
plt.legend(prop={'size':20},loc='upper left')
plt.xlabel(r'$M_{D}$(GeV)',size=25)
plt.ylabel(r'$M_S$(GeV)',size=25)
plt.xlim(1e2,10e3)
plt.ylim(3e1,1e4)

plt.subplot(122)

plt.semilogx(h2.mChi1, h2.BRx1x1h2h2/100.,'bo',label=r'$\chi_1^0\chi_1^0\to h_2h_2$')
plt.semilogx(xd2.mChi1, (xd2.BRxx2d1U1+xd2.BRxx2d2U2+xd2.BRxx2d3U3)/100.,'m^',label=r'$\chi^+\chi_2^0\to d_i\bar{u}_i$')
plt.semilogx(xd2.mChi1, (xd2.BRxx2e1Nu1+xd2.BRxx2e2Nu2+xd2.BRxx2e3Nu3)/100.,'gd',label=r'$\chi^-\chi_2^0\to e_i\bar{\nu}_i$')

#plt.grid()
plt.legend(prop={'size':16},loc='best')
plt.xlabel(r'$m_{\chi_1^0}$(GeV)',size=25)
plt.ylabel(r'$\%\,$ Contribution $\to$ DM',size=18)
plt.xlim(1e2,2e3)
plt.ylim(0.01,1.05)

plt.tight_layout()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## P-Wave sigma v

# %% [markdown]
# \begin{equation}
# \sigma v_r \approx \dfrac{h_c^4 (Z^H_{11})^4(1-\mu^2)(9-8\mu^2+2\mu^4) }{192 \pi\, m_{\chi}^2 (2-\mu^2)^4} \color{red}{v_r^4} = d \color{red}{v_r^4} \to
# \langle\sigma v_r\rangle \approx \dfrac{h_c^4 (Z^H_{11})^4(1-\mu^2)(9-8\mu^2+2\mu^4) }{192 \pi\, m_{\chi}^2 (2-\mu^2)^4} \color{red}{\dfrac{20}{x_f^2} }
# \end{equation}

# %% [markdown]
# Conversion factor:
# $3\times 10^{-26} cm^2/s \approx 2.54 \times 10^{-9} GeV^{-2}$

# %%
def sigmav(hc,ZH,u,m,xf):
    conver = 3.*10**(-26)/(2.54*10**(-9))
    siv = hc**4*ZH**4*(1.-u**2)*(9.-8.*u**2+2.*u**4)*3./(192.*np.pi*m**2*(2.-u**2)**4*xf)*conver
    return siv

# %%
XF = 25

# %%
#Add to the DataFrame
h2['sv_fr_ana'] = sigmav(h2.YRC,h2.ZH11,h2.mh2/h2.mChi1,h2.mChi1,XF)

# %%
h2[['sv','sv_fr_ana']][:3]
# Out:
#              sv     sv_fr_ana
# 0  2.900000e-31  2.121078e-26
# 1  2.800000e-31  2.251835e-26
# 2  2.870000e-31  1.878327e-26

# %%
plt.figure(figsize=(16,6))

plt.subplot(121)
plt.loglog(h2.mChi1, h2.mh2, 'ro')
plt.xlabel(r'$m_{\chi^0_1}$(GeV)',size=25)
plt.ylabel(r'$m_{h_2}$(GeV)',size=25)

a = np.linspace(100,2000,10)
plt.plot(a,a,'b--')

plt.subplot(122)
plt.loglog(h2.mChi1, h2.mh2/h2.mChi1, 'ro')
plt.hlines(1,100,2000,'b')
plt.xlabel(r'$m_{\chi^0_1}$(GeV)',size=25)
plt.ylabel(r'$m_{h_2}/m_{\chi^0_1}$',size=25)

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.loglog(h2.mChi1 , h2.sv_fr_ana, 'co')

plt.hlines(3.e-26,1e2,2e3, 'r')
plt.xlabel(r'$m_{\chi^0}$(GeV)',size=25)
plt.ylabel(r'$\langle\sigma v\rangle $ $($cm$^{3} $s$^{-1})$',size=25)

plt.show()

# %% [markdown]
# Ok. Near to $3\times 10^{-26}$ WIMP miracle

# %% [markdown]
# # Relic Density $\Omega h^2$

# %% [markdown]
# \begin{equation}
# \Omega h^2 = \dfrac{0.876\times 10^{-10}x_f}{\sqrt{g^{*}}}\dfrac{1}{\langle \sigma v_r\rangle}\to
# \dfrac{0.876\times 10^{-10}x_f}{\sqrt{g^{*}}}\dfrac{1}{\left(a+\dfrac{3b}{x_f}+\cdots\right)}
# \end{equation}

# %%
conver = 3.*10**(-26)/(2.54*10**(-9))

# %%
h2['Omega_ana'] = 0.876*1e-10*XF/np.sqrt(90)*1./(h2.sv_fr_ana/conver)

# %%
plt.figure(figsize=(8,6))

plt.hlines(0.12, 1e2, 2e3, 'b')
plt.loglog(h2.mChi1 , h2.Omega_ana, 'co',label=r'$\Omega$ (ana)')
plt.loglog(h2.mChi1 , h2.Omega, 'ro',label=r'$\Omega$')
plt.legend(prop={'size':18},loc='best')
plt.xlabel(r'$m_{\chi^0}$(GeV)',size=25)
plt.ylabel(r'$\Omega h^2$',size=25)

plt.show()

# %%
h2.columns
# Out:
# Index(['MDF', 'MS12', 'MS22', 'LamS1H', 'LamS2H', 'LamSPH', 'LamS', 'LamSP',
#        'vS', 'YRD', 'YRC', 'mh1', 'mh2', 'mv3', 'mv2', 'mv1', 'mS1', 'mS2',
#        'mCha', 'mChi1', 'mChi2', 'XV11', 'XV12', 'XV21', 'XV22', 'XU11',
#        'XU12', 'XU21', 'XU22', 'vevSM', 'Omega', 'PSI', 'PSD', 'NSI', 'NSD',
#        'T', 'S', 'U', 'mueg', 'taumug', 'sv', 'ZH11', 'ZH12', 'ZH21', 'ZH22',
#        'BRh1gg', 'BRh2gg', 'BRx1x1u1U1', 'BRx1x1u2U2', 'BRx1x1u3U3',
#        'BRx1x1d1D1', 'BRx1x1d2D2', 'BRx1x1d3D3', 'BRx1x1e1E1', 'BRx1x1e2E2',
#        'BRx1x1e3E3', 'BRxx2d1U1', 'BRxx2d2U2', 'BRxx2d3U3', 'BRxx2e1Nu1',
#        'BRxx2e2Nu2', 'BRxx2e3Nu3', 'BRx1x1h1h1', 'BRx1x1h2h2', 'BRx1x1h1h2',
#        'BRx1x1gg', 'BRx1x1ww', 'BRx1x1ZZ', 'BRxxww', 'BRx2x2ww', 'Xf',
#        'vsigmaeff', 'BRS', 'sv_fr_ana', 'Omega_ana'],
#       dtype='object')

# %%
h2[['sv','sv_fr_ana']]
# Out:
#                sv     sv_fr_ana
# 0    2.900000e-31  2.121078e-26
# 1    2.800000e-31  2.251835e-26
# 2    2.870000e-31  1.878327e-26
# 3    2.770000e-31  2.044209e-26
# 4    1.860000e-31  4.298650e-27
# 5    2.740000e-31  2.054798e-26
# 6    2.780000e-31  1.521739e-26
# 7    3.010000e-31  2.817022e-26
# 8    2.860000e-31  2.636106e-26
# 9    4.430000e-31  2.692135e-26
# 10   2.810000e-31  2.636747e-26
# 11   2.860000e-31  2.626058e-26
# 12   2.900000e-31  2.637762e-26
# 13   4.260000e-31  3.811141e-26
# 14   1.580000e-30  2.581677e-26
# 15   2.950000e-31  2.489854e-26
# 16   3.010000e-31  2.839263e-26
# 17   2.990000e-31  2.739780e-26
# 18   3.000000e-31  2.799488e-26
# 19   2.830000e-31  2.547806e-26
# 20   2.980000e-31  2.748740e-26
# 21   1.950000e-31  5.066089e-27
# 22   2.780000e-31  2.612714e-26
# 23   2.890000e-31  2.658718e-26
# 24   2.900000e-31  2.687356e-26
# 25   2.870000e-31  2.593296e-26
# 26   2.820000e-31  2.659648e-26
# 27   7.720000e-31  2.610417e-26
# 28   2.870000e-31  2.704994e-26
# 29   2.790000e-31  2.327703e-26
# ..            ...           ...
# 71   2.490000e-31  9.503152e-27
# 72   2.710000e-31  2.265306e-26
# 73   2.990000e-31  2.817494e-26
# 74   2.120000e-29  2.627960e-26
# 75   3.020000e-31  2.841781e-26
# 76   3.240000e-31  2.668254e-26
# 77   2.850000e-31  2.619692e-26
# 78   2.970000e-31  2.683345e-26
# 79   3.250000e-31  1.860472e-26
# 80   2.910000e-31  2.691516e-26
# 81   2.890000e-31  2.725197e-26
# 82   2.810000e-31  2.470483e-26
# 83   2.750000e-31  2.379028e-26
# 84   2.940000e-31  2.573552e-26
# 85   3.660000e-29  9.352343e-27
# 86   3.610000e-31  3.370724e-26
# 87   7.900000e-31  1.348263e-26
# 88   2.720000e-31  1.740662e-26
# 89   2.890000e-31  1.718108e-26
# 90   2.050000e-30  2.859007e-26
# 91   2.920000e-31  2.651560e-26
# 92   2.250000e-31  7.133549e-27
# 93   2.940000e-30  2.709787e-26
# 94   3.950000e-31  2.834515e-26
# 95   5.170000e-31  7.189030e-27
# 96   3.020000e-31  2.777867e-26
# 97   3.000000e-31  2.454452e-26
# 98   2.860000e-31  2.545094e-26
# 99   2.870000e-31  2.563224e-26
# 100  2.430000e-31  8.109695e-27
#
# [101 rows x 2 columns]
